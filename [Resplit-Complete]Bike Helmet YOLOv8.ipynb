# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT_DIR = '/content/drive/My Drive/AdvancedComputerVision/Augmented_Bike_Helmet_Dataset'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.2/663.2 kB 8.3 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

# load the model
model = YOLO("yolov8n.yaml")

# use the model
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=100, task="detect")  # train the model
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# save the train and validation results
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !scp -r /content/runs '/content/drive/My Drive/AdvancedComputerVision/Augmented_Bike_Helmet_Dataset'

# %%
# load the best pretrained model
model = YOLO("/content/drive/My Drive/AdvancedComputerVision/Augmented_Bike_Helmet_Dataset/runs/detect/train/weights/best.pt")

# test the model
metrics = model.val(data=os.path.join(ROOT_DIR, "data.yaml"), split="test")
# Out:
# Ultralytics YOLOv8.0.229 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 50.8MB/s]
# val: Scanning /content/drive/My Drive/AdvancedComputerVision/Augmented_Bike_Helmet_Dataset/augmented_test/labels... 375 images, 10 backgrounds, 0 corrupt: 100%|██████████| 375/375 [00:29<00:00, 12.91it/s]
# val: New cache created: /content/drive/My Drive/AdvancedComputerVision/Augmented_Bike_Helmet_Dataset/augmented_test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 24/24 [00:08<00:00,  2.92it/s]
#                    all        375       1193      0.854      0.728      0.812      0.424
#            With Helmet        375        811      0.884       0.82      0.883      0.483
#         Without Helmet        375        382      0.824      0.636      0.742      0.364
# ...

# %%
# save the validation results
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !scp -r /content/runs '/content/drive/My Drive/AdvancedComputerVision/Augmented_Bike_Helmet_Dataset'

# %%
# load the largest YOLO model
model = YOLO("yolov8x.yaml")

# train the model
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=30, task="detect")  # train the model
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
# ...

# %%
# load the largest YOLO model
model = YOLO('/content/drive/My Drive/AdvancedComputerVision/Augmented_Bike_Helmet_Dataset/runs/detect/train/weights/best.pt')

# train the model
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=70, task="detect")  # train the model
# Out:
# Ultralytics YOLOv8.0.229 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
# test the model
metrics = model.val(data=os.path.join(ROOT_DIR, "data.yaml"), split="test")
# Out:
# Ultralytics YOLOv8.0.229 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8x summary (fused): 268 layers, 68125494 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/drive/My Drive/AdvancedComputerVision/Augmented_Bike_Helmet_Dataset/augmented_test/labels.cache... 375 images, 10 backgrounds, 0 corrupt: 100%|██████████| 375/375 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 24/24 [00:18<00:00,  1.29it/s]
#                    all        375       1193      0.892       0.83      0.889      0.507
#            With Helmet        375        811      0.916       0.89      0.934      0.557
#         Without Helmet        375        382      0.867       0.77      0.844      0.457
# Speed: 0.2ms preprocess, 20.5ms inference, 0.0ms loss, 3.0ms postprocess per image
# Results saved to runs/detect/train32

# %%
model.predict('/content/drive/My Drive/AdvancedComputerVision/custom_video_2.mp4', save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1837) /content/drive/My Drive/AdvancedComputerVision/custom_video_2.mp4: 384x640 (no detections), 16.0ms
# video 1/1 (2/1837) /content/drive/My Drive/AdvancedComputerVision/custom_video_2.mp4: 384x640 (no detections), 17.9ms
# video 1/1 (3/1837) /content/drive/My Drive/AdvancedComputerVision/custom_video_2.mp4: 384x640 (no detections), 16.5ms
# ...

# %%
# save the test results
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !scp -r /content/runs/detect/train34 '/content/drive/My Drive/AdvancedComputerVision/Augmented_Bike_Helmet_Dataset'
